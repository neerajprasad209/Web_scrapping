# %% [markdown]
# # Web Scraping

# %%
import requests 
from bs4 import BeautifulSoup as bs 
from urllib.request import urlopen as uReq 
import logging

# %%
link = "https://www.flipkart.com/search?q=" +"iphone14"

# %%
link
# Out:
# 'https://www.flipkart.com/search?q=iphone14'

# %%
urlclient = uReq(link)

# %%
flipkart_page = urlclient.read()

# %%
flipkart_html = bs(flipkart_page,"html.parser")

# %%
bigbox = flipkart_html.find_all("div",{"class" : "_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 31

# %%
del bigbox[0:3]

# %%
bigbox[3].div.div.div.a['href']
# Out:
# '/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAY05S0C&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=a86280da-f989-42b0-9e47-64ceb715c256.MOBGHWFHSV7GUFWA.SEARCH&ppt=None&ppn=None&ssid=9pamm2nxkg0000001690908255784&qH=694e31eb1200eb29'

# %%
product_link = "https://www.flipkart.com"+"/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAY05S0C&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=ecb73235-7176-43cd-8c32-0e088ada069b.MOBGHWFHSV7GUFWA.SEARCH&ppt=None&ppn=None&ssid=8m7c7y4ysg0000001690788974046&qH=694e31eb1200eb29"

# %%
prodReq = requests.get(product_link)

# %%
prodReq.encoding='utf-8'

# %%
prod_html = bs(prodReq.text,"html.parser")

# %%
print(prod_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = prod_html.find_all("div",{"class":"_16PBlm"})

# %%
comment_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Just wow!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Good</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_6f073baa94184fa582db3440228389ed.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_ed12b87f38d14546850096e9bcd7dbf0.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Avi Nash</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><c
# ...

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAY05S0C&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=ecb73235-7176-43cd-8c32-0e088ada069b.MOBGHWFHSV7GUFWA.SEARCH&ppt=None&ppn=None&ssid=8m7c7y4ysg0000001690788974046&qH=694e31eb1200eb29'

# %%
product_html = bs(product_req.text)

# %%
comment_box = product_html.find_all("div", {"class": "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Avi Nash'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Avi Nash
# Tara singh mehra
# Narendar Redyy
# Ajay Kumar
# Shivam  kumar
# Ashwini  biswal
# Rahul Prasad
# SUNNY KUMAR
# Kajapriya Kannan
# Abhijeet Ghumare
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.find_all("div",{"class":"_3LWZlK _1BLPMq"})[0].text)
# Out:
# 5
# 5
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.find_all("div",{"class":"_3LWZlK _1BLPMq"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Just wow!
# Great product
# Very Good
# Brilliant
# Terrific purchase
# Good quality product
# Fabulous!
# Just wow!
# Best in the market!
# Best in the market!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":"t-ZTKy"})[0].text)
# Out:
# GoodREAD MORE
# Nice camera but battery drain fast specially on video recordingREAD MORE
# Nice UI and FastREAD MORE
# Just amazing!READ MORE
# Thanku filipkart best phone in the world ❤️READ MORE
# Awesome 👍READ MORE
# Best smart phone under this price range compare to other phones in 2023 if you see overall build quality, performance and Camera with autofocus and video action mode are awesome50% extra RAM compared to iPhone 13 and other more features. Best time to upgrade to iPhone 14 . I am so happy See Low light photos are amazing..READ MORE
# I used iPhone 12 mini and now upgraded with iPhone 14. Camera quality is awesome.Full day battery backup.Super Retina display with high dynamic range is awesome.In terms of camera and battery life is big upgrade for me.READ MORE
# Performance is really good and camera quality is fineREAD MORE
# Best in class in all the aspects. Top notch performance for display, camera and everything.READ MORE
# ...

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HVXY5AV&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=3d955170-ebbd-4ab1-8e2f-31d864fc43d0.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=lypwm2fzk00000001690790366752&qH=694e31eb1200eb29
# https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXSSCYWA&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=3d955170-ebbd-4ab1-8e2f-31d864fc43d0.MOBGHWFHECFVMDCX.SEARCH&ppt=None&ppn=None&ssid=lypwm2fzk00000001690790366752&qH=694e31eb1200eb29
# ...
